# %% [markdown]
# # Capstone 1

# %% [markdown]
# In this assignment, you should to create a new repository on your Github account and name it Coursera_Capstone.
# After that you should to create a Jupyter Notebook and submit a shareable link to it for peer evaluation.

# %% [markdown]
# Now, start a Jupyter Notebook using any platform that you are comfortable with and do the following:

# %% [markdown]
# 1. Write some markdown to explain that this notebook will be mainly used for the capstone project.
# 2. Import the pandas library as pd.
# 3. Import the Numpy library as np.
# 4. Print the following the statement: Hello Capstone Project Course!

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
